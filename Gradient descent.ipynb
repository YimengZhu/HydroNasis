# %%
import numpy
import numpy as np
import pandas as pd
import csv

# %%
data_train = pd.read_csv('M15.csv')
#将csv文件数据读成矩阵
list = data_train.values.tolist()
data = np.array(list)

# %%
#特征缩放
means = data.mean()
stds = data.std()
data_ = data
data_train.describe()
x = (data - data.mean()) / data.std()

#真实值
r = x[:,6]

#删除真实值
x = np.delete(x,[6],axis=1)
m = x.shape[0]
n = x.shape[1]
r = r.reshape((m,1))
p = np.random.rand(n,1)

# %%
#梯度下降
cost = np.zeros(3000)
alpha = 0.01

for i in range(2999):
    y = np.matmul(x,p)
    error = y - r
    cost[i] = np.matmul(error.T,error) / (2 * m)
    z = np.matmul(x.T,error)
    p = p - alpha * z / my = np.matmul(x,p)
error = y - r
cost[2999] = np.matmul(error.T,error) / (2 * m)

# %%
print('代价函数cost:',cost)
print('参数p:',p)
print('预测系统稳态均值',y)
# Out:
# 代价函数cost: [1.13111706e+01 8.07686658e+00 7.13811109e+00 ... 1.86054854e-04
#  1.86043380e-04 1.86031926e-04]
# 参数p: [[ 4.75051664e-01]
#  [-1.44926659e-01]
#  [ 2.03642321e-01]
#  [ 4.07047485e-01]
#  [ 2.27251385e-01]
#  [ 8.28447028e-02]
#  [-4.07574883e-01]
#  [ 1.77536295e-01]
#  [ 4.69797068e-01]
#  [-3.51937429e-01]
#  [ 2.37299363e-01]
#  [-1.82672434e-01]
#  [ 4.86881548e-01]
#  [ 1.21207925e-01]
#  [ 2.22214923e-01]
#  [-2.02090554e-01]
#  [ 1.08838034e-01]
#  [-2.68763609e-01]
#  [ 4.42536580e-01]
#  [ 4.34975139e-01]
#  [ 3.06108308e-01]
#  [ 3.84269628e-01]
#  [-3.26814807e-01]
#  [-2.71871132e-01]
#  [-1.47020021e-01]
#  [-4.49244156e-01]
#  [-4.22287680e-01]
#  [ 3.49695351e-01]
#  [-1.17499381e-01]
#  [-4.86131138e-01]
#  [-1.06174944e-02]
#  [ 2.07026282e-01]
#  [-3.55670450e-01]
#  [-3.71694671e-01]
#  [ 7.79043011e-02]
#  [-1.53952854e-02]
#  [-1.13014341e-01]
#  [ 1.26339829e-01]
#  [-6.50905387e-02]
#  [-1.55625400e-03]
#  [ 3.66033221e-01]
#  [ 7.88508246e-02]
# ...
